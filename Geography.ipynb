# %%
import requests
import bs4
import json

# %%
#geotectonics

#1
questions=[]

result=requests.get("https://www.gkseries.com/general-knowledge/geography/geo-tectonics/geography-mcqs")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
#for 2nd page
result_2=requests.get('https://www.gkseries.com/general-knowledge/geography/geo-tectonics/00002-geo-tectonics')
soup = bs4.BeautifulSoup(result_2.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
    
    
#3
result_2=requests.get("https://www.gkseries.com/general-knowledge/geography/geo-tectonics/3-geo-tectonics-objective-questions-and-answers")
soup = bs4.BeautifulSoup(result_2.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
    
    
#4
result_2=requests.get("https://www.gkseries.com/general-knowledge/geography/geo-tectonics/4-geo-tectonics-quiz-questions-and-answers")
soup = bs4.BeautifulSoup(result_2.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
    
#5
result_2=requests.get("https://www.gkseries.com/general-knowledge/geography/geo-tectonics/5-geo-tectonics-questions-and-answers-on-earth")
soup = bs4.BeautifulSoup(result_2.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
    
#6
result_2=requests.get("https://www.gkseries.com/general-knowledge/geography/geo-tectonics/6-geo-tectonics-interview-questions-and-answer")
soup = bs4.BeautifulSoup(result_2.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
    
#7-8
base_url='https://www.gkseries.com/general-knowledge/geography/geo-tectonics/{}-geo-tectonics-objective-questions-and-answers'

for n in range(7,9):
    
    scrape_url = base_url.format(n)
    res = requests.get(scrape_url)
    
    soup= bs4.BeautifulSoup(res.text,'lxml')
    
    for item in soup.select('.mcq'):
        a_list=item.text.split()
        a_list.remove('View')
        a_list.remove('Answer')
        a_list.remove('Comment')
        new_string=" ".join(a_list)
        
        questions.append(new_string)
            

#9
result_2=requests.get("https://www.gkseries.com/general-knowledge/geography/geo-tectonics/9-geo-tectonics-quiz-questions-and-answers")
soup = bs4.BeautifulSoup(result_2.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
    

    
#10-11
base_url='https://www.gkseries.com/general-knowledge/geography/geo-tectonics/{}-geo-tectonics-interview-questions-and-answer'
for n in range(10,12):
    
    scrape_url = base_url.format(n)
    res = requests.get(scrape_url)
    
    soup= bs4.BeautifulSoup(res.text,'lxml')
    
    for item in soup.select('.mcq'):
        a_list=item.text.split()
        a_list.remove('View')
        a_list.remove('Answer')
        a_list.remove('Comment')
        new_string=" ".join(a_list)
        
        questions.append(new_string)
        
        
#12
result_2=requests.get("https://www.gkseries.com/general-knowledge/geography/geo-tectonics/12-geo-tectonics-objective-questions-and-answers")
soup = bs4.BeautifulSoup(result_2.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
    
result_homewebsite=requests.get("https://www.gkseries.com/general-knowledge/gk-subjects")
soup = bs4.BeautifulSoup(result_homewebsite.text,"lxml")
        
a=soup.find_all("h4")[0].getText()
b=soup.select("div.list-group")[0].getText().split()[0]
schema={"Topic":a,"Subject":b,"data":questions}
json_object=json.dumps(schema,indent=4)

with open("geotectonic.json",'w') as json_file:
    json_file.write(json_object)
    
json_file.close()

# %%
#geomorphology
#for 1-2 page

questions=[]
base_url_1='https://www.gkseries.com/general-knowledge/geography/geomorphology/0000{}-geomorphology'
for n in range(1,3):
    
    scrape_url = base_url_1.format(n)
    res = requests.get(scrape_url)
    
    soup= bs4.BeautifulSoup(res.text,'lxml')
    
    for item in soup.select('.mcq'):
        a_list=item.text.split()
        a_list.remove('View')
        a_list.remove('Answer')
        a_list.remove('Comment')
        new_string=" ".join(a_list)
        
        questions.append(new_string)
        

#for 3rd page
a=requests.get("https://www.gkseries.com/general-knowledge/geography/geomorphology/3-geomorphology-quiz-questions-and-answers")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
    
#for 4th page
b=requests.get("https://www.gkseries.com/general-knowledge/geography/geomorphology/4-geomorphology-geography-mcq-questions-and-answers-for-competitive-exams")
soup = bs4.BeautifulSoup(b.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string) 

    
#for 5th page
c=requests.get("https://www.gkseries.com/general-knowledge/geography/geomorphology/5-geomorphology-geography-mcq-questions-and-answers-for-upsc-exam")
soup = bs4.BeautifulSoup(c.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
    
    
#for 6th page
d=requests.get("https://www.gkseries.com/general-knowledge/geography/geomorphology/6-ssc-examination-multiple-choice-questions-and-answers-on-geomorphology-geography")
soup = bs4.BeautifulSoup(d.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
    
    
    
#for pages 7 to 29
base_url_2='https://www.gkseries.com/general-knowledge/geography/geomorphology/geomorphology-geography-mcq-questions-and-answers-for-competitive-exams-{}'
for n in range(7,30):
    
    scrape_url_2 = base_url_2.format(n)
    res = requests.get(scrape_url_2)
    
    soup= bs4.BeautifulSoup(res.text,'lxml')
    
    for item in soup.select('.mcq'):
        
        a_list=item.text.split()
        a_list.remove('View')
        a_list.remove('Answer')
        a_list.remove('Comment')
        new_string=" ".join(a_list)
        questions.append(new_string)
        
result_homewebsite=requests.get("https://www.gkseries.com/general-knowledge/gk-subjects")
soup = bs4.BeautifulSoup(result_homewebsite.text,"lxml")
        
a=soup.find_all("h4")[0].getText()
b=soup.select("div.list-group")[0].getText().split()[1]
schema={"Topic":a,"Subject":b,"data":questions}
json_object=json.dumps(schema,indent=4)

with open("geomorphology.json",'w') as json_file:
    json_file.write(json_object)
    
json_file.close()

# %%
#oceanography
#for 1st page
questions=[]

a=requests.get("https://www.gkseries.com/general-knowledge/geography/oceanography/geography-questions-on-oceanography")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
    
    
#for 2nd page
b=requests.get("https://www.gkseries.com/general-knowledge/geography/oceanography/00002-geography-questions-on-oceanography")
soup = bs4.BeautifulSoup(b.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
    

base_url_3='https://www.gkseries.com/general-knowledge/geography/oceanography/{}-oceanography-questions-and-answers'    
#for pages 3 to 9
for n in range(3,10):
    
    scrape_url_3 = base_url_3.format(n)
    res = requests.get(scrape_url_3)
    
    soup= bs4.BeautifulSoup(res.text,'lxml')
    
    for item in soup.select('.mcq'):
        
        
        a_list=item.text.split()
        a_list.remove('View')
        a_list.remove('Answer')
        a_list.remove('Comment')
        new_string=" ".join(a_list)
        questions.append(new_string)
        
result_homewebsite=requests.get("https://www.gkseries.com/general-knowledge/gk-subjects")
soup = bs4.BeautifulSoup(result_homewebsite.text,"lxml")
        
a=soup.find_all("h4")[0].getText()
b=soup.select("div.list-group")[0].getText().split()[2]
schema={"Topic":a,"Subject":b,"data":questions}
json_object=json.dumps(schema,indent=4)

with open("oceanography.json",'w') as json_file:
    json_file.write(json_object)
json_file.close()

# %%
#climatography
#1
questions=[]

a=requests.get("https://www.gkseries.com/general-knowledge/geography/climatology/questions-and-answers")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
    
#2
a=requests.get("https://www.gkseries.com/general-knowledge/geography/climatology/2-mcq-questions-and-answers")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
    
    
#3
a=requests.get("https://www.gkseries.com/general-knowledge/geography/climatology/3-quiz-questions-and-answers-on-climatology")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
    
    
#4
a=requests.get("https://www.gkseries.com/general-knowledge/geography/climatology/4-mcq-quiz-questions-on-climate")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#5
a=requests.get("https://www.gkseries.com/general-knowledge/geography/climatology/5-climatology-objective-questions-and-answers")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#6
a=requests.get("https://www.gkseries.com/general-knowledge/geography/climatology/6-climatology-short-questions-and-answers")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#7-8
base='https://www.gkseries.com/general-knowledge/geography/climatology/{}-climatology-questions-and-answers-for-competitive-exams'
for n in range(7,9):
    
    scrape = base.format(n)
    res = requests.get(scrape)
    
    soup= bs4.BeautifulSoup(res.text,'lxml')
    
    for item in soup.select('.mcq'):
        a_list=item.text.split()
        a_list.remove('View')
        a_list.remove('Answer')
        a_list.remove('Comment')
        new_string=" ".join(a_list)
        questions.append(new_string)
#9
a=requests.get("https://www.gkseries.com/general-knowledge/geography/climatology/9-climatology-multiple-choice-questions-and-answers")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)

#10
a=requests.get("https://www.gkseries.com/general-knowledge/geography/climatology/10-climatology-quiz")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#11
a=requests.get("https://www.gkseries.com/general-knowledge/geography/climatology/11-general-knowledge-questions-and-answers-on-climatology")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#12
a=requests.get("https://www.gkseries.com/general-knowledge/geography/climatology/12-gk-questions-and-answers-on-climatology")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)

  
  
base_url='https://www.gkseries.com/general-knowledge/geography/climatology/{}-general-awareness-questions-and-answers-on-climatology'
for n in range(13,15):
    
    scrape_url = base_url.format(n)
    res = requests.get(scrape_url)
    
    soup= bs4.BeautifulSoup(res.text,'lxml')
    
    for item in soup.select('.mcq'):
        a_list=item.text.split()
        a_list.remove('View')
        a_list.remove('Answer')
        a_list.remove('Comment')
        new_string=" ".join(a_list)
        questions.append(new_string)

#15
a=requests.get("https://www.gkseries.com/general-knowledge/geography/climatology/15-general-awareness-mcq-questions-and-answers-on-climatology")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
    
result_homewebsite=requests.get("https://www.gkseries.com/general-knowledge/gk-subjects")
soup = bs4.BeautifulSoup(result_homewebsite.text,"lxml")
        
    
a=soup.find_all("h4")[0].getText()
b=soup.select("div.list-group")[0].getText().split()[3]
schema={"Topic":a,"Subject":b,"data":questions} 
json_object=json.dumps(schema,indent=4)

with open("climatography.json",'w') as json_file:
    json_file.write(json_object)
    
json_file.close()

# %%
#regional geography
#1
questions=[]

a=requests.get("https://www.gkseries.com/general-knowledge/geography/regional-geography/multiple-choice-questions-and-answers-on-regional-geography-1")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
    

#2
a=requests.get("https://www.gkseries.com/general-knowledge/geography/regional-geography/gk-mcqs-with-answers-on-regional-geography-2")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#3
a=requests.get("https://www.gkseries.com/general-knowledge/geography/regional-geography/objective-questions-and-answers-on-regional-geography-3")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#4
a=requests.get("https://www.gkseries.com/general-knowledge/geography/regional-geography/regional-geography-gk-questions-and-answers-4")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#5
a=requests.get("https://www.gkseries.com/general-knowledge/geography/regional-geography/general-awareness-questions-and-answers-on-indian-geography-5")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#6
a=requests.get("https://www.gkseries.com/general-knowledge/geography/regional-geography/general-knowledge-questions-and-answers-on-indian-geography-6")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#7
a=requests.get("https://www.gkseries.com/general-knowledge/geography/regional-geography/quiz-questions-and-answers-on-indian-geography-7")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#8
a=requests.get("https://www.gkseries.com/general-knowledge/geography/regional-geography/multiple-choice-questions-and-answers-on-indian-geography-8")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)

#9-48
base_url='https://www.gkseries.com/general-knowledge/geography/regional-geography/gk-mcqs-with-answers-on-indian-geography-{}'
for n in range(9,49):
    
    scrape_url = base_url.format(n)
    res = requests.get(scrape_url)
    
    soup= bs4.BeautifulSoup(res.text,'lxml')
    
    for item in soup.select('.mcq'):
        
        a_list=item.text.split()
        a_list.remove('View')
        a_list.remove('Answer')
        a_list.remove('Comment')
        new_string=" ".join(a_list)
        questions.append(new_string)

result_homewebsite=requests.get("https://www.gkseries.com/general-knowledge/gk-subjects")
soup = bs4.BeautifulSoup(result_homewebsite.text,"lxml")

a=soup.find_all("h4")[0].getText()
b=soup.select("div.list-group")[0].getText().split()[4]
schema={"Topic":a,"Subject":b,"data":questions}
json_object=json.dumps(schema,indent=4)


with open("regionalgeography.json",'w') as json_file:
    json_file.write(json_object)
    
json_file.close()

# %%
#biogeography
questions=[]
#1
a=requests.get("https://www.gkseries.com/general-knowledge/geography/biogeography/biogeography-questions-and-answers")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)


#2    
a=requests.get("https://www.gkseries.com/general-knowledge/geography/biogeography/biogeography-gk-multiple-choice-questions-and-answers-2")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#3    
a=requests.get("https://www.gkseries.com/general-knowledge/geography/biogeography/biogeography-gk-objective-type-questions-and-answers-3")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#4    
a=requests.get("https://www.gkseries.com/general-knowledge/geography/biogeography/biogeography-gk-mcq-questions-and-answers-4")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
    
#5
a=requests.get("https://www.gkseries.com/general-knowledge/geography/biogeography/biogeography-gk-quiz-questions-and-answers-5")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)    


#6-27
base_url='https://www.gkseries.com/general-knowledge/geography/biogeography/biogeography-gk-mcq-questions-and-answers-{}'
for n in range(6,28):
    
    scrape_url = base_url.format(n)
    res = requests.get(scrape_url)
    
    soup= bs4.BeautifulSoup(res.text,'lxml')
    
    for item in soup.select('.mcq'):
        
        a_list=item.text.split()
        a_list.remove('View')
        a_list.remove('Answer')
        a_list.remove('Comment')
        new_string=" ".join(a_list)
        questions.append(new_string)
        

result_homewebsite=requests.get("https://www.gkseries.com/general-knowledge/gk-subjects")
soup = bs4.BeautifulSoup(result_homewebsite.text,"lxml")
        
a=soup.find_all("h4")[0].getText()
b=soup.select("div.list-group")[0].getText().split()[5]
schema={"Topic":a,"Subject":b,"data":questions}
json_object=json.dumps(schema,indent=4)

with open("biogeography.json",'w') as json_file:
    json_file.write(json_object)
    
json_file.close()

# %%
#enviormental geography
questions=[]
a=requests.get("https://www.gkseries.com/general-knowledge/geography/environmental-geography/environmental-geography-multiple-choice-questions-and-answers")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)

result_homewebsite=requests.get("https://www.gkseries.com/general-knowledge/gk-subjects")
soup = bs4.BeautifulSoup(result_homewebsite.text,"lxml")
        

a=soup.find_all("h4")[0].getText()
b=soup.select("div.list-group")[0].getText().split()[7]
schema={"Topic":a,"Subject":b,"data":questions}
json_object=json.dumps(schema,indent=4)
    
with open("enviormentalgeography.json",'w') as json_file:
    json_file.write(json_object)
    
    
json_file.close()


#solar system
#1
questions=[]

a=requests.get("https://www.gkseries.com/general-knowledge/geography/solar-system/1-solar-system-gk-multiple-choice-questions-and-answers")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#2
a=requests.get("https://www.gkseries.com/general-knowledge/geography/solar-system/2-solar-system-gk-objective-type-questions-and-answers")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#3
a=requests.get("https://www.gkseries.com/general-knowledge/geography/solar-system/3-solar-system-gk-quiz-questions-and-answers")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#4
a=requests.get("https://www.gkseries.com/general-knowledge/geography/solar-system/4-gk-mcqs-with-answers-on-solar-system")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)
#5-6
base_url='https://www.gkseries.com/general-knowledge/geography/solar-system/{}-general-awareness-multiple-choice-questions-and-answers-on-solar-system'
for n in range(5,7):
    
    scrape_url = base_url.format(n)
    res = requests.get(scrape_url)
    
    soup= bs4.BeautifulSoup(res.text,'lxml')
    
    for item in soup.select('.mcq'):
        
        
        a_list=item.text.split()
        a_list.remove('View')
        a_list.remove('Answer')
        a_list.remove('Comment')
        new_string=" ".join(a_list)
        questions.append(new_string)

result_homewebsite=requests.get("https://www.gkseries.com/general-knowledge/gk-subjects")
soup = bs4.BeautifulSoup(result_homewebsite.text,"lxml")
        

a=soup.find_all("h4")[0].getText()

schema={"Topic":a,"Subject":'Solar',"data":questions}
json_object=json.dumps(schema,indent=4)


with open("solarsystem.json",'w') as json_file:
    
    json_file.write(json_object)
json_file.close()

# %%
#economic geography
#1

questions=[]
a=requests.get("https://www.gkseries.com/general-knowledge/geography/economic-geography/economic-geography-multiple-choice-questions-and-answers")
soup = bs4.BeautifulSoup(a.text,"lxml")
for item in soup.select('.mcq'):
    
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
    questions.append(new_string)


#2-22
base_url='https://www.gkseries.com/general-knowledge/geography/economic-geography/economic-geography-multiple-choice-questions-and-answers-{}'
for n in range(2,23):
    
    scrape_url = base_url.format(n)
    res = requests.get(scrape_url)
    
    soup= bs4.BeautifulSoup(res.text,'lxml')
    
    for item in soup.select('.mcq'):
        
        a_list=item.text.split()
        a_list.remove('View')
        a_list.remove('Answer')
        a_list.remove('Comment')
        new_string=" ".join(a_list)
        questions.append(new_string)
        
result_homewebsite=requests.get("https://www.gkseries.com/general-knowledge/gk-subjects")
soup = bs4.BeautifulSoup(result_homewebsite.text,"lxml")
        

a=soup.find_all("h4")[0].getText()
schema={"Topic":a,"Subject":"Economic","data":questions}
json_object=json.dumps(schema,indent=4)


with open("economicgeography.json",'w') as json_file:
    json_file.write(json_object)
    
    
    
json_file.close()
