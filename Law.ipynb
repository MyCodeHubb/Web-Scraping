# %%
import requests
import bs4
import json

# %%
#Constitutional and administrative
questions=[]


#1-2
base_url='https://www.gkseries.com/general-knowledge/law-quiz/constitutional-and-administrative-law/0000{}-constitutional-and-administrative-law'
for n in range(1,3):
    
    scrape_url = base_url.format(n)
    res = requests.get(scrape_url)
    
    soup= bs4.BeautifulSoup(res.text,'lxml')
    
    for item in soup.select('.mcq'):
        a_list=item.text.split()
        a_list.remove('View')
        a_list.remove('Answer')
        a_list.remove('Comment')
        new_string=" ".join(a_list)
        
        questions.append(new_string)
#3               
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/constitutional-and-administrative-law/3-objective-questions-on-constitutional-and-administrative-law")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
#4               
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/constitutional-and-administrative-law/4-mcqs-with-answers-on-constitutional-law")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)

    
#5              
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/constitutional-and-administrative-law/5-law-general-awareness-questions-and-answers-on-indian-constitution")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
    
    
#6               
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/constitutional-and-administrative-law/6-indian-constitutional-law-gk-questions-and-answers")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
    
#7               
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/constitutional-and-administrative-law/7-quiz-on-indian-constitution")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
#8               
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/constitutional-and-administrative-law/8-indian-constitution-general-knowledge-questions-and-answers")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
    
#9               
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/constitutional-and-administrative-law/9-law-mcqs-on-indian-administration")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)    
    
#10               
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/constitutional-and-administrative-law/10-law-gk-on-indian-administration")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)

    
#11               
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/constitutional-and-administrative-law/11-law-gk-on-indian-constitution")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
#12               
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/constitutional-and-administrative-law/12-law-multiple-choice-questions-and-answers-on-indian-constitution")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
    
schema={"Topic":"Law","Subject":"Constitutional and Administrative","data":questions}
json_object=json.dumps(schema,indent=4)
with open("administrativelaw.json",'w') as json_file:
    json_file.write(json_object)
    
json_file.close()

# %%
#hindu law
questions=[]


#1-2
base_url='https://www.gkseries.com/general-knowledge/law-quiz/hindu-law/0000{}-hindu-law-questions-and-answers'
for n in range(1,3):
    
    scrape_url = base_url.format(n)
    res = requests.get(scrape_url)
    
    soup= bs4.BeautifulSoup(res.text,'lxml')
    
    for item in soup.select('.mcq'):
        a_list=item.text.split()
        a_list.remove('View')
        a_list.remove('Answer')
        a_list.remove('Comment')
        new_string=" ".join(a_list)
        
        questions.append(new_string)
        
#3              
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/hindu-law/3-hindu-law-mcqs-with-answers")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
    
#4               
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/hindu-law/4-objective-questions-on-hindu-law-with-answers")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
    
    
#5               
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/hindu-law/5-hindu-law-questions-and-answers-for-judicial-services-exam")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
    
#6              
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/hindu-law/6-hindu-law-gk-questions-and-answers-for-judicial-services-exam")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
    
#7               
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/hindu-law/7-judicial-services-exam-mcqs-and-answers-on-previous-year-questions")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
        
schema={"Topic":"Law","Subject":"Hindu Law","data":questions}
json_object=json.dumps(schema,indent=4)
with open("hindulaw.json",'w') as json_file:
    json_file.write(json_object)
    
json_file.close()

# %%
#ipc codes
questions=[]
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/indian-penel-code/indian-penel-code-multiple-choice-questions-and-answers")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
        
schema={"Topic":"Law","Subject":"Indian Penel Code","data":questions}
json_object=json.dumps(schema,indent=4)
with open("ipc.json",'w') as json_file:
    json_file.write(json_object)
    
json_file.close()

# %%
#civil procedure codes
questions=[]
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/code-of-civil-procedure/code-of-civil-procedure-cpc-multiple-choice-questions-and-answers")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
        
schema={"Topic":"Law","Subject":"Code of Civil Procedure","data":questions}
json_object=json.dumps(schema,indent=4)
with open("cpc.json",'w') as json_file:
    json_file.write(json_object)
    
json_file.close()

# %%
#code of criminal p
questions=[]
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/code-of-criminal-procedure/code-of-criminal-procedure-crpc-multiple-choice-questions-and-answers")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
        
schema={"Topic":"Law","Subject":"Code of Criminal Procedure","data":questions}
json_object=json.dumps(schema,indent=4)
with open("crpc.json",'w') as json_file:
    json_file.write(json_object)
    
json_file.close()

# %%
#law of contract
questions=[]
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/law-of-contract/law-of-contract-multiple-choice-questions-and-answers")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
        
schema={"Topic":"Law","Subject":"Contract","data":questions}
json_object=json.dumps(schema,indent=4)
with open("contract.json",'w') as json_file:
    json_file.write(json_object)
    
json_file.close()

# %%
#limitation act

questions=[]
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/law-of-limitation-act/limitation-act-multiple-choice-questions-and-answers")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
        
schema={"Topic":"Law","Subject":"Limitation Act","data":questions}
json_object=json.dumps(schema,indent=4)
with open("limitationact.json",'w') as json_file:
    json_file.write(json_object)
    
json_file.close()

# %%
#indian evidence act

questions=[]
result=requests.get("https://www.gkseries.com/general-knowledge/law-quiz/indian-evidence-act/indian-evidence-act-multiple-choice-questions-and-answers")
soup = bs4.BeautifulSoup(result.text,"lxml")
for item in soup.select('.mcq'):
    
    a_list=item.text.split()
    a_list.remove('View')
    a_list.remove('Answer')
    a_list.remove('Comment')
    new_string=" ".join(a_list)
        
    questions.append(new_string)
        
schema={"Topic":"Law","Subject":"Indian Evidence Act","data":questions}
json_object=json.dumps(schema,indent=4)
with open("evidenceact.json",'w') as json_file:
    json_file.write(json_object)
    
json_file.close()
